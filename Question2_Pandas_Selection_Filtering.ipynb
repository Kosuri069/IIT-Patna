# %%
import pandas as pd

data = [
    {"EmployeeID": 201, "Name": "Sarah",    "Department": "Engineering", "Salary": 85000, "Performance Score": 4, "Years of Service": 5},
    {"EmployeeID": 202, "Name": "Michael",  "Department": "Sales",       "Salary": 62000, "Performance Score": 3, "Years of Service": 3},
    {"EmployeeID": 203, "Name": "Jennifer", "Department": "Marketing",   "Salary": 71000, "Performance Score": 5, "Years of Service": 7},
    {"EmployeeID": 204, "Name": "David",    "Department": "Engineering", "Salary": 92000, "Performance Score": 5, "Years of Service": 8},
    {"EmployeeID": 205, "Name": "Lisa",     "Department": "HR",          "Salary": 58000, "Performance Score": 4, "Years of Service": 4},
    {"EmployeeID": 206, "Name": "James",    "Department": "Sales",       "Salary": 68000, "Performance Score": 4, "Years of Service": 6},
    {"EmployeeID": 207, "Name": "Emma",     "Department": "Engineering", "Salary": 78000, "Performance Score": 3, "Years of Service": 2},
    {"EmployeeID": 208, "Name": "Robert",   "Department": "Marketing",   "Salary": 75000, "Performance Score": 4, "Years of Service": 5},
    {"EmployeeID": 209, "Name": "Sophia",   "Department": "Sales",       "Salary": 65000, "Performance Score": 5, "Years of Service": 4},
    {"EmployeeID": 210, "Name": "William",  "Department": "HR",          "Salary": 60000, "Performance Score": 3, "Years of Service": 3},
]

employees_df = pd.DataFrame(data)
employees_df
# Out:
#    EmployeeID      Name   Department  Salary  Performance Score  \
# 0         201     Sarah  Engineering   85000                  4
# 1         202   Michael        Sales   62000                  3
# 2         203  Jennifer    Marketing   71000                  5
# 3         204     David  Engineering   92000                  5
# 4         205      Lisa           HR   58000                  4
# 5         206     James        Sales   68000                  4
# 6         207      Emma  Engineering   78000                  3
# 7         208    Robert    Marketing   75000                  4
# 8         209    Sophia        Sales   65000                  5
# 9         210   William           HR   60000                  3
#
#    Years of Service
# 0                 5
# 1                 3
# 2                 7
# 3                 8
# 4                 4
# 5                 6
# 6                 2
# 7                 5
# 8                 4
# 9                 3

# %%
employees_df[["Name", "Department", "Salary"]]
# Out:
#        Name   Department  Salary
# 0     Sarah  Engineering   85000
# 1   Michael        Sales   62000
# 2  Jennifer    Marketing   71000
# 3     David  Engineering   92000
# 4      Lisa           HR   58000
# 5     James        Sales   68000
# 6      Emma  Engineering   78000
# 7    Robert    Marketing   75000
# 8    Sophia        Sales   65000
# 9   William           HR   60000

# %%
employees_df.iloc[5]
# Out:
# EmployeeID             206
# Name                 James
# Department           Sales
# Salary               68000
# Performance Score        4
# Years of Service         6
# Name: 5, dtype: object

# %%
employees_by_id = employees_df.set_index("EmployeeID")
employees_by_id.loc[208]
# Out:
# Name                    Robert
# Department           Marketing
# Salary                   75000
# Performance Score            4
# Years of Service             5
# Name: 208, dtype: object

# %%
employees_df.loc[employees_df["EmployeeID"] == 208]
# Out:
#    EmployeeID    Name Department  Salary  Performance Score  Years of Service
# 7         208  Robert  Marketing   75000                  4                 5

# %%
employees_df[employees_df["Department"] == "Engineering"]
# Out:
#    EmployeeID   Name   Department  Salary  Performance Score  Years of Service
# 0         201  Sarah  Engineering   85000                  4                 5
# 3         204  David  Engineering   92000                  5                 8
# 6         207   Emma  Engineering   78000                  3                 2

# %%
employees_df[employees_df["Salary"] > 70000]
# Out:
#    EmployeeID      Name   Department  Salary  Performance Score  \
# 0         201     Sarah  Engineering   85000                  4
# 2         203  Jennifer    Marketing   71000                  5
# 3         204     David  Engineering   92000                  5
# 6         207      Emma  Engineering   78000                  3
# 7         208    Robert    Marketing   75000                  4
#
#    Years of Service
# 0                 5
# 2                 7
# 3                 8
# 6                 2
# 7                 5

# %%
employees_df.sort_values("Salary", ascending=False).head(3)
# Out:
#    EmployeeID   Name   Department  Salary  Performance Score  Years of Service
# 3         204  David  Engineering   92000                  5                 8
# 0         201  Sarah  Engineering   85000                  4                 5
# 6         207   Emma  Engineering   78000                  3                 2

# %%
employees_df.sort_values(["Department", "Salary"], ascending=[True, False])
# Out:
#    EmployeeID      Name   Department  Salary  Performance Score  \
# 3         204     David  Engineering   92000                  5
# 0         201     Sarah  Engineering   85000                  4
# 6         207      Emma  Engineering   78000                  3
# 9         210   William           HR   60000                  3
# 4         205      Lisa           HR   58000                  4
# 7         208    Robert    Marketing   75000                  4
# 2         203  Jennifer    Marketing   71000                  5
# 5         206     James        Sales   68000                  4
# 8         209    Sophia        Sales   65000                  5
# 1         202   Michael        Sales   62000                  3
#
#    Years of Service
# 3                 8
# 0                 5
# 6                 2
# 9                 3
# 4                 4
# 7                 5
# 2                 7
# 5                 6
# 8                 4
# 1                 3
